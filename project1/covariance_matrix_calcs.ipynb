# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
df_mut = pd.read_table('TCGA.STAD.expression.txt', sep='\t')
df_meta = pd.read_table('TCGA.STAD.metadata.txt', sep='\t')
char_to_exclude = '?'
columns_to_exclude = [col for col in df_mut.columns if char_to_exclude in col]
df_mut = df_mut.drop(columns=columns_to_exclude)
print(df_mut)
# Out:
#        patient_id                     sample_id     A1BG|1  A1CF|29974  \
# 0    TCGA-CG-4460  TCGA-CG-4460-01A-01R-1157-13  93.052200   12.340600
# 1    TCGA-CG-5716  TCGA-CG-5716-01A-21R-1802-13  84.107200   34.691300
# 2    TCGA-HF-7131  TCGA-HF-7131-01A-11R-2055-13  12.191900  524.253000
# 3    TCGA-3M-AB46  TCGA-3M-AB46-01A-11R-A414-31  38.520380    4.920650
# 4    TCGA-3M-AB47  TCGA-3M-AB47-01A-22R-A414-31  45.368918   76.903904
# ..            ...                           ...        ...         ...
# 442  TCGA-CG-4469  TCGA-CG-4469-01A-01R-1157-13  14.710811         NaN
# 443  TCGA-CG-4474  TCGA-CG-4474-01A-02R-1157-13  37.764156         NaN
# 444  TCGA-CG-4475  TCGA-CG-4475-01A-01R-1157-13  16.769487         NaN
# 445  TCGA-CG-4476  TCGA-CG-4476-01A-01R-1157-13  24.972112         NaN
# 446  TCGA-CG-4477  TCGA-CG-4477-01A-01R-1157-13  24.412300         NaN
#
#      A2BP1|54715  A2LD1|87769         A2M|2  A2ML1|144568  A4GALT|53947  \
# 0      72.809500   108.239000  17955.100000     27.972000    139.449000
# 1       1.284900    89.805600  13303.000000      0.642400    216.500000
# 2       0.000000    58.134600  14486.700000      0.348300    197.509000
# 3       0.242018   237.505651   6199.018529     -0.158680    104.677489
# 4      13.255733   163.843799  24942.252968      0.528090    342.608883
# ..           ...          ...           ...           ...           ...
# 442          NaN   216.301691   7958.348831      0.284409     65.942861
# 443          NaN   196.576418  21828.685179     -0.413655    198.237729
# 444          NaN    68.148995  20825.993496      0.954869    482.385233
# 445          NaN   169.264644  34248.674797      0.226252    263.314493
# 446          NaN   132.496787  14783.897918   2214.996943    249.948511
#
#      A4GNT|51146  ...  ZWILCH|55055  ZWINT|11130   ZXDA|7789  ZXDB|158586  \
# 0     241.053000  ...    591.728000  1451.670000   80.213900  1075.690000
# 1     118.207000  ...    636.297000  1378.020000   60.388600   396.380000
# 2     126.448000  ...    501.890000   927.981000   41.452600   575.111000
# 3      -0.045474  ...   1059.705900  5391.562305   21.581673   324.650328
# 4       1.902523  ...    640.857369   777.926162   19.721401   541.495266
# ..           ...  ...           ...          ...         ...          ...
# 442     0.867064  ...    839.475066   982.037922  179.864210  1398.494311
# 443    43.026944  ...    745.532095  1056.917140   39.429966   349.337898
# 444     0.687272  ...    556.284407   655.851549   59.290240   554.447507
# 445    90.722338  ...    516.997610   608.014394   45.332473   464.399520
# 446    52.281169  ...    923.544322  1637.419633   43.536092   424.897766
#
#       ZXDC|79364  ZYG11A|440590  ZYG11B|79699      ZYX|7791  ZZEF1|23140  \
# 0    1403.950000       4.113500    804.607000   2491.980000  1650.350000
# 1     753.573000       2.569700    568.552000   6013.160000  3154.340000
# 2     883.741000       0.348300    780.632000  10838.600000  2024.910000
# 3     729.272388      16.359688   1001.110984   2480.909953   743.714284
# 4     813.305313       2.579701    925.875739   3513.264885  1456.136359
# ..           ...            ...           ...           ...          ...
# 442   913.757621       1.845753    953.276441   2789.057736  1119.313995
# 443   970.055609      17.164493    757.811259   4264.469081  2702.668453
# 444  1308.788955       3.756246    927.963540   3103.609391  1370.141309
# 445  1101.931239       0.301440    845.677334   3302.569055  1915.477072
# 446  1010.009621     217.431795    859.078048   2497.814797  1247.130940
#
#       ZZZ3|26009
# 0    1488.280000
# 1     559.558000
# 2     623.530000
# 3     813.625564
# 4     881.152305
# ..           ...
# 442  1091.778096
# 443   857.336078
# 444   473.853001
# 445  1027.285482
# 446   916.155785
#
# [447 rows x 20504 columns]

# %%
df_num1 = df_mut.select_dtypes(exclude=['object'])
#df_num2 = df_mut.select_dtypes(exclude=['object'])
#df_e = df_num2.dropna(axis=1)
#df_num = df_merge.select_dtypes(exclude=['object'])
df_e = df_num1.dropna(axis=1)
log2df = df_e.apply(lambda x: np.log2(x + 2))
filtered_df = log2df[log2df.mean(skipna=True).nlargest(500).index]
df_e_norm = StandardScaler().fit_transform(filtered_df)
df_merge = pd.concat([df_meta, pd.DataFrame(df_e_norm, columns = filtered_df.columns)], axis=1)
df_cov = df_merge.select_dtypes(exclude=['object'])
cov_matrix = df_cov.cov()
print("Covariance Matrix:")
print(cov_matrix)
# Out:
# Covariance Matrix:
#                                      age_at_initial_pathologic_diagnosis  \
# age_at_initial_pathologic_diagnosis                           115.497650
# OS                                                              0.373964
# OS.time                                                      -709.977559
# DSS                                                            -0.126588
# DSS.time                                                     -709.977559
# ...                                                                  ...
# GLG1|2734                                                      -0.800182
# SFPQ|6421                                                      -0.142812
# SPARCL1|8404                                                    0.370651
# ADAM9|8754                                                      0.274864
# PAPOLA|10914                                                   -0.113043
#
#                                             OS        OS.time        DSS  \
# age_at_initial_pathologic_diagnosis   0.373964    -709.977559  -0.126588
# OS                                    0.237472     -54.991838   0.160747
# OS.time                             -54.991838  291611.728918 -31.377983
# DSS                                   0.160747     -31.377983   0.186694
# DSS.time                            -54.991838  291611.728918 -31.377983
# ...                                        ...            ...        ...
# GLG1|2734                            -0.003534      48.703391   0.022065
# SFPQ|6421                            -0.034612      25.213305  -0.020309
# SPARCL1|8404                          0.019307     -29.360876  -0.001177
# ADAM9|8754                            0.041773      27.939729   0.013142
# PAPOLA|10914                          0.011705      71.652899   0.004858
#
#                                           DSS.time        DFI       DFI.time  \
# age_at_initial_pathologic_diagnosis    -709.977559  -0.207254   -1060.224870
# OS                                      -54.991838   0.070008     -51.992190
# OS.time                              291611.728918 -19.141789  304898.507113
# DSS                                     -31.377983   0.088728     -33.604479
# DSS.time                             291611.728918 -19.141789  304898.507113
# ...                                            ...        ...            ...
# GLG1|2734                                48.703391  -0.024706     103.464005
# SFPQ|6421                                25.213305   0.017301       0.208912
# SPARCL1|8404                            -29.360876   0.000455      26.141305
# ADAM9|8754                               27.939729  -0.014069      23.334983
# PAPOLA|10914                             71.652899  -0.019770      67.252834
#
#                                            PFI       PFI.time  Redaction  ...  \
# age_at_initial_pathologic_diagnosis  -0.529501    -564.808191        NaN  ...
# OS                                    0.111926     -61.059053        NaN  ...
# OS.time                             -10.974513  276607.753554        NaN  ...
# DSS                                   0.159429     -45.987080        NaN  ...
# DSS.time                            -10.974513  276607.753554        NaN  ...
# ...                                        ...            ...        ...  ...
# GLG1|2734                             0.038752      36.111277        NaN  ...
# SFPQ|6421                             0.012300      21.362418        NaN  ...
# SPARCL1|8404                         -0.024927     -21.420183        NaN  ...
# ADAM9|8754                            0.017639      26.172000        NaN  ...
# PAPOLA|10914                          0.007224      68.996849        NaN  ...
#
#                                      SEC62|7095  ARCN1|372  TCP1|6950  \
# age_at_initial_pathologic_diagnosis   -0.706288  -0.214309   0.236185
# OS                                     0.026315   0.024549   0.010128
# OS.time                               12.862358  19.629542  35.030172
# DSS                                    0.029972   0.031174   0.022648
# DSS.time                              12.862358  19.629542  35.030172
# ...                                         ...        ...        ...
# GLG1|2734                             -0.010432   0.164208  -0.158820
# SFPQ|6421                             -0.159548   0.059011   0.447047
# SPARCL1|8404                           0.281062  -0.073063  -0.405506
# ADAM9|8754                            -0.019945   0.331466   0.191950
# PAPOLA|10914                           0.037733   0.234970   0.499801
#
#                                      CNOT1|23019  COL5A1|1289  GLG1|2734  \
# age_at_initial_pathologic_diagnosis    -0.311704    -0.798084  -0.800182
# OS                                      0.006505     0.045259  -0.003534
# OS.time                                55.750225   -37.263823  48.703391
# DSS                                     0.028502     0.013817   0.022065
# DSS.time                               55.750225   -37.263823  48.703391
# ...                                          ...          ...        ...
# GLG1|2734                               0.356604     0.377965   1.002242
# SFPQ|6421                               0.124612    -0.101728  -0.035368
# SPARCL1|8404                           -0.174052     0.355693   0.279598
# ADAM9|8754                              0.144313     0.053606   0.164384
# PAPOLA|10914                            0.255856    -0.198841  -0.043090
#
#                                      SFPQ|6421  SPARCL1|8404  ADAM9|8754  \
# age_at_initial_pathologic_diagnosis  -0.142812      0.370651    0.274864
# OS                                   -0.034612      0.019307    0.041773
# OS.time                              25.213305    -29.360876   27.939729
# DSS                                  -0.020309     -0.001177    0.013142
# DSS.time                             25.213305    -29.360876   27.939729
# ...                                        ...           ...         ...
# GLG1|2734                            -0.035368      0.279598    0.164384
# SFPQ|6421                             1.002242     -0.509500   -0.083837
# SPARCL1|8404                         -0.509500      1.002242   -0.141854
# ADAM9|8754                           -0.083837     -0.141854    1.002242
# PAPOLA|10914                          0.368302     -0.357965    0.132700
#
#                                      PAPOLA|10914
# age_at_initial_pathologic_diagnosis     -0.113043
# OS                                       0.011705
# OS.time                                 71.652899
# DSS                                      0.004858
# DSS.time                                71.652899
# ...                                           ...
# GLG1|2734                               -0.043090
# SFPQ|6421                                0.368302
# SPARCL1|8404                            -0.357965
# ADAM9|8754                               0.132700
# PAPOLA|10914                             1.002242
#
# [510 rows x 510 columns]

# %%
# Convert DataFrame to numpy array if needed
data_array = df_e.values
cov_matrix_np = np.cov(data_array, rowvar=False)
print("NumPy Covariance Matrix:")
print(cov_matrix_np)
# Out:
# NumPy Covariance Matrix:
# [[ 2.35661761e-01  1.06384366e-01  1.38065457e+00 ...  3.50323420e+01
#    8.79094701e-01  1.05482724e+00]
#  [ 1.06384366e-01  2.14745037e-01  2.78378927e+00 ...  1.31829154e+01
#   -8.01355605e+00 -1.61651757e-01]
#  [ 1.38065457e+00  2.78378927e+00  3.79993456e+03 ... -9.68182391e+02
#   -2.62914663e+03 -2.53140861e+03]
#  ...
#  [ 3.50323420e+01  1.31829154e+01 -9.68182391e+02 ...  5.74652173e+06
#    4.91678553e+03 -9.76528950e+04]
#  [ 8.79094701e-01 -8.01355605e+00 -2.62914663e+03 ...  4.91678553e+03
#    6.31581766e+05  1.90073253e+04]
#  [ 1.05482724e+00 -1.61651757e-01 -2.53140861e+03 ... -9.76528950e+04
#    1.90073253e+04  5.46965081e+04]]

# %%
plt.figure()
sns.heatmap(cov_matrix, annot=False, fmt='.2f', cmap='coolwarm', 
            xticklabels=df_cov.columns, yticklabels=df_cov.columns)
plt.title('Covariance Matrix Heatmap')
plt.show()

# %%
corr_matrix = df_cov.corr()
print("\nCorrelation Matrix:")
print(corr_matrix)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', 
            xticklabels=df.columns, yticklabels=df.columns)
plt.title('Corr Matrix Heatmap')
plt.show()

# %%
corr2_matrix = df_meta.select_dtypes(exclude=['object']).corr()
print("\nCorrelation Matrix:")
print(corr2_matrix)
# Out:
# Correlation Matrix:
#                                      age_at_initial_pathologic_diagnosis  \
# age_at_initial_pathologic_diagnosis                             1.000000
# OS                                                              0.071247
# OS.time                                                        -0.125308
# DSS                                                            -0.027351
# DSS.time                                                       -0.125308
# DFI                                                            -0.049271
# DFI.time                                                       -0.176878
# PFI                                                            -0.104912
# PFI.time                                                       -0.100892
# Redaction                                                            NaN
#
#                                            OS   OS.time       DSS  DSS.time  \
# age_at_initial_pathologic_diagnosis  0.071247 -0.125308 -0.027351 -0.125308
# OS                                   1.000000 -0.209140  0.777951 -0.209140
# OS.time                             -0.209140  1.000000 -0.132809  1.000000
# DSS                                  0.777951 -0.132809  1.000000 -0.132809
# DSS.time                            -0.209140  1.000000 -0.132809  1.000000
# DFI                                  0.429829 -0.089559  0.738494 -0.089559
# DFI.time                            -0.218995  0.978682 -0.188830  0.978682
# PFI                                  0.490618 -0.043416  0.779758 -0.043416
# PFI.time                            -0.234099  0.955914 -0.194884  0.955914
# Redaction                                 NaN       NaN       NaN       NaN
#
#                                           DFI  DFI.time       PFI  PFI.time  \
# age_at_initial_pathologic_diagnosis -0.049271 -0.176878 -0.104912 -0.100892
# OS                                   0.429829 -0.218995  0.490618 -0.234099
# OS.time                             -0.089559  0.978682 -0.043416  0.955914
# DSS                                  0.738494 -0.188830  0.779758 -0.194884
# DSS.time                            -0.089559  0.978682 -0.043416  0.955914
# DFI                                  1.000000 -0.207610  0.959526 -0.196669
# DFI.time                            -0.207610  1.000000 -0.172397  0.978117
# PFI                                  0.959526 -0.172397  1.000000 -0.195585
# PFI.time                            -0.196669  0.978117 -0.195585  1.000000
# Redaction                                 NaN       NaN       NaN       NaN
#
#                                      Redaction
# age_at_initial_pathologic_diagnosis        NaN
# OS                                         NaN
# OS.time                                    NaN
# DSS                                        NaN
# DSS.time                                   NaN
# DFI                                        NaN
# DFI.time                                   NaN
# PFI                                        NaN
# PFI.time                                   NaN
# Redaction                                  NaN

# %%
plt.figure(figsize=(20, 16))
sns.heatmap(corr2_matrix, annot=True, fmt='.2f', cmap='coolwarm', 
            xticklabels=df_meta.select_dtypes(exclude=['object']).columns, yticklabels=df_meta.select_dtypes(exclude=['object']).columns)
plt.title('Corr Matrix Heatmap')
plt.show()
